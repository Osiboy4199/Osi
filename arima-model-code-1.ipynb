# %%
#Importing the data set
STOCK.PRICES = read.csv(choose.files(),header = TRUE)
attach(STOCK.PRICES)
str(STOCK.PRICES)
library(fBasics)
options(scipen = 999)
library(tseries)
sink("Result5.doc")
basicStats(data.frame(PRICE))
sink()
T= ts(PRICE)
sink("Result1.doc")
qwe = ts(STOCK.PRICES)
adf.test(PRICE)
sink()
PICES
library(astsa, quietly = TRUE, warn.conflicts = FALSE)
library(ggplot2)
library(DescTools)
library(knitr)
library(printr)
library(plyr)
library(dplyr)
library(lubridate)
library(gridExtra)
library(reshape2)
library(TTR)
plot.ts(DifferencePRICERAW,ylab = "Stock Prices",xlab = "Daily Trade",col = "blue")
LogPRICE = log(PRICE)
View(LogPRICE)
Logdifference = diff(LogPRICE)
sink("Result9.doc")
View(Logdifference)

plot.ts(PRICE, ylab = "Stock Prices",xlab = "Daily Trade",col = "blue")
sink()
print(Logdifference)
plot(Logdifference)
DifferencePRICERAW = diff(PRICE)
df = data.frame(DifferencePRICERAW)
ggplot(df = qwe,
        mapping = aes(x = DATE, y = PRICE))+
  geom_point()
rdata = 
  as.Date(PRICE$DATE,"%m/%d/%y")
theplot= ggplot(df,ylab = "Stock Prices",xlab = "Daily Trade",col = "blue")
theplot
ggplot(df=DifferencePRICERAW,mapping = des(x=DATE,y=PRICE))
data()

View(DifferencePRICERAW)
plot(PRICE,ylab = "Stock Prices",xlab = "Daily Trade",col = "blue")
sink("Result2.doc")
adf.test(DifferencePRICERAW)
#Converting your data to timeseries
DifferencePRICEtime = ts(DifferencePRICERAW)
class(DifferencePRICEtime)
View(DifferencePRICEtime)
#we have to open two packages
library(forecast)
library(tseries)
plot(DifferencePRICEtime)
#then we check the auto-correlation
acf(DifferencePRICEtime)
#drawing arima model
arimamodel = auto.arima(DifferencePRICEtime,ic="aic",trace = TRUE)
ar=pacf(DifferencePRICEtime)
arimamodel
acf(ts(arimamodel$residuals))
acf(arimamodel$residuals)
fg=arimamodel$residuals
acfplot(fg)
acf(fg)
Acf(fg)
Box.test(arimamodel$residuals)
#we forecast using the model 20 days ahead
mydataforecast = forecast(arimamodel,level = c(95),h=20)
autoplot(mydataforecast)
mydataforecast
View(mydataforecast)
plot(mydataforecast)
plot.ts(PRICE,mydataforecast,)
#we validated using Box-Test
Box.test(mydataforecast$residuals, lag = 5, type = "Ljung-Box")
Box.test(mydataforecast$residuals, lag = 15, type = "Ljung-Box")
length(PRICE)


library(zoo)
casedat = zoo(STOCK.PRICES$PRICE,seq(from = as.Date("2020-01-01"), to = as.Date("2021-10-01"),by = 3))
autoplot(casedat)+xlab("DAY")+ylab("STOCK PRICES")
library(ggfortify)

casedat1 = zoo(mydataforecast,seq(from = as.Date("2021-10-01"), to = as.Date("2021-10-21"),by = 1))
autoplot(casedat1)+xlab("DAY")+ylab("STOCK PRICES")
autoplot(mydataforecast)
newplot = cbind(casedat,casedat1)
autoplot(newplot,facets = F)

STOCK.PRICES1 = read.csv("BEANS DATA.csv",header = TRUE)
View(STOCK.PRICES1)

datadeck_raw = read.csv(choose.files(), header = F, skip = 1, stringsAsFactors = F)
View(datadeck_raw)
